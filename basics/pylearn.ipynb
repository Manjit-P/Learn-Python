# %% [markdown]
# # Python Crash Course

# %% [markdown]
# # String

# %%
name = 'ada lovelace'
print(name[0]) #can be indexed but is immutable.
print(name.title()) #capitalizes each word after a whitespace

# %%
name.upper() #changes to capital letters

# %%
name.lower() #changes to small letters

# %%
first_name = 'ada'
last_name = 'lovelace'
full_name = f"    {first_name} {last_name}  " #assigning using f-string.
print(f"Hello, {full_name.title()}")

# %%
full_name.rstrip() #strips whitespaces on the right side of the string.
full_name.lstrip() #strips whitespaces on the left side of the string.
full_name.strip()  #strips whitespaces from both sides.

# %%
url = "https://hellow.com/"
url.removeprefix('https://')
url.removesuffix('/')

# %% [markdown]
# # Integer & Float

# %%
10000_10000_00000 #underscore for better readability.
4/2 # division in python always produces float.
4//2 #floor division will yield integer if both are integer else float.

# %% [markdown]
# # Lists []
# name of list should always be plural. (Programmer convention)

# %%
alphabets = ['a', 'b', 'c', 'd', 'e']
alphabets.append('f') #adds 'f' at the end of the list.
alphabets.insert(0,'z') # add a value at any index in a list.
del alphabets[0] #removes element at index 0.
alphabets.pop() #pops an element from list.
alphabets.remove('b') #removes element by value.
alphabets.sort() #sorts in ascending order (works in both numbers and string).
alphabets.sort(reverse= True) #sorts in descending order (works in both numbers and string).
sorted(alphabets) #prints in sorted manneer but keeps the original order).
alphabets.reverse() #reverses the list.
len(alphabets) #returns length of the list.

# %%
digits = [value for value in range(1,10)] #list comprehension.
my_foods = ['pizza', 'falafel', 'carrot cake']
friends_food = my_foods #this will use friends_food as alias for the same list.
friend_foods = my_foods[:] # this will create a copy of existing list.

# %% [markdown]
# # Tuples ()
# immutable list
# single element tuple is rare but if created it must have trailing comma(tuple_name = (3, ))

# %%
dimensions = (200, 100)
print(f"orignial:\n {dimensions[1]}, {dimensions[0]}")
dimensions = (400, 200) #tuple itself is not modified but reassigned with different values.
print(f"modified:\n {dimensions[1]}, {dimensions[0]}")

# %% [markdown]
# # Dictionary {}
# key-value pair

# %%
alien_0 = {'color': 'green', 'points': 5}
print(alien_0['color'])
print(alien_0['points'])
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)
alien_0['color'] = 'yellow'
print(alien_0)

# %%
alien_0 = {'x_position': 0, 'y_position': 25, 'speed': 'medium'}
print(f'Original position: {alien_0["x_position"]}')

# Move the alien to the right.
# Determine how far to move the alien based on its current speed. 
if alien_0['speed'] == 'slow':
    x_increment = 1
elif alien_0['speed'] == 'medium':
    x_increment = 2
else:
    # This must be a fast alien.
    x_increment = 3

# The new position is the old position plus the increment.
alien_0['x_position'] = alien_0['x_position'] + x_increment

print(f'New position: {alien_0["x_position"]}')

# %%
del alien_0['points']
print(alien_0)

# %%
point = alien_0.get('points', 'No point value assigned.') # used to retrieve value if key is assigned i.e. a way of getting around the error.
print(point)

# %%
user_0 = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
}

# %%
user_0.items() # returns all key-value pairs
user_0.keys() # returns all the keys
user_0.values() # returns all the values

# %% [markdown]
# Nesting dictionary inside list.

# %%
# Make an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)

# Show how many aliens have been created.
print(f'Total number of aliens:{len(aliens)}')

# %% [markdown]
# Nesting list inside dictionary.

# %%
fav_language = {
    'jen': ['python', 'rust'],
    'sarah': ['c'],
    'edward': ['go', 'rust'],
    'phil': ['python', 'haskell'],

}

for name, languages in fav_language.items():
    print(f'\n{name.title()} chose:')
    for language in languages:
        print(language)

# %% [markdown]
# Dictionary Nesting

# %%
users = {
    'aeinstein':
         {
            'first': 'albert',
            'last': 'einstein',
            'location': 'princeton',
         },

    'mcurie': {
            'first': 'albert',
            'last': 'einstein',
            'location': 'princeton',
         },
         
         }

for username, user_info in users.items():
    print(f'\nUsername: {username}')
    full_name = f'{user_info['first']} {user_info['last']}'
    location = user_info['location']

    print(f'Full name: {full_name.title()}')
    print(f'Location: {location.title()}')

# %% [markdown]
# input() will treat the input value as string.
# We should explicitly change the type of the value.

# %%
prompt = "\nTell me something, and I will repeat it back to you:\n Enter 'quit' to end the program"
message = ""
active = True
while active:
    message = input(prompt)
    if message == 'quit':
        active = False
    else:
        print(message)

# %%
unconfirmed_users = ['alice', 'brian', 'candance']
confirmed_users = []

while unconfirmed_users:
    current_user = unconfirmed_users.pop() 

    print(f"Verifying user: {current_user.title()}")
    confirmed_users.append(current_user)

print('\nThe following users have been confirmed: ')
for confirmed_user in confirmed_users:
    print(confirmed_user.title())

# %%
pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)

while 'cat' in pets:
    pets.remove('cat')

print(pets)

# %%
responses = {}
# Setting the flag to indicate that polling is active
polling_active = True

while polling_active:
    # Prompt for the person's name and response.
    name = input("\nWhat is your name? ")
    response = input("Which mountain would you like to climb someday? ")

    # Store the response in the dictionary.
    responses[name] = response

    # asking the user to continue the poll or not.
    repeat = input("Would you like to let another person respond? (y/n) ")

    if repeat == 'n':
        polling_active = False

# Polling is complete. Show the results.
print("\n--- Poll Results ---")
for name, response in responses.items():
    print(f"{name.title()} would like to climb {response.title()}.")

# %% [markdown]
# Optional argument

# %%
def get_formatted_name(first, last, middle=''):
    '''returns formatted full name'''
    if middle:
        full_name = f'{first} {middle} {last}'
    else:
        full_name = f'{first} {last}'

    return full_name.title()

print(get_formatted_name('pai', 'lai', 'vai'))
print(get_formatted_name('pai','vai'))

# %% [markdown]
# Returning a dictionary from a function

# %%
hello = {}
isactive = True

while isactive:
    name = input('Name: ')
    location = input ('location: ')
    age = int(input('age'))
    hello[name]= {'location': location, 
                  'age': age,
                  }
    
    repeat = input("(y/n)")

    if repeat == 'n':
        isactive = False

# %%
unprinted_designs = ['phone case', 'robot pendant', 'dodecahedron']
completed_models = []

def print_models(unprinted_designs, completed_models):
    '''
    Simulate printing each design, until none are left.
    Move each design to completed_models after printing.
    '''
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        print(f"Printing model: {current_design}")
        completed_models.append(current_design)

def show_completed_models():
    '''Show all the modesl that were printed.'''
    print("\nThe following modesl have been printed:")
    for completed_model in completed_models:
        print(completed_model)

print_models(unprinted_designs[:], completed_models)
show_completed_models()

# %%
def make_pizza(*toppings):
    '''Prints the list of toppings that have been requested.'''
    print("\nMaking a pizza with toppings: ")
    for topping in toppings:
        print(f"- {topping}")

make_pizza('pepperoni')
make_pizza('pepperoni', 'green peppers', 1)

# %%
def build_profile(first, last, **user_info):
    '''Build a dictionary containing everything we know about a user.'''
    user_info['first_name'] = first
    user_info['last_name'] = last
    
    return user_info

user_profile = build_profile('albert', 'einstein', location='princeton', field= 'physics')
print(user_profile)

# %%
class Dog:
    '''A simple attempt to model a dog.'''

    def __init__(self, name, age):
        '''Initialize name and age attributes.'''
        self.name = name
        self.age = age
    
    def sit(self):
        '''Simulate a dog sittings in response to a command.'''
        print(f"{self.name} is now sitting.")

    def roll_over(self):
        '''Simulate a dog rolling over in response to a command.'''
        print(f"{self.name} rolled over!")

my_dog = Dog('Willie', 6)
your_dog = Dog('Lucy', 3)

print(f"My dog's name is {my_dog.name}")
print(f"My dog is {my_dog.age}")
my_dog.sit()

print(f"\nYour dog's name is {your_dog.name}")
print(f"Your dog is {your_dog.age}")
your_dog.roll_over()

# %%
class Car:
    '''A simple attempt to represent a car.'''

    def __init__(self, make, model, year):
        '''Initialize attributes to describe a car.'''
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        self.fuelcapacity = 25

    def get_descriptive_name(self):
        '''Return a neatly formatted descriptive name.'''
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()
    
    def fuel_capacity(self):
        '''Print a statement showing the car's fuel capacity.'''
        print(f"This car has fuel capacity of {self.fuelcapacity}L.")

    def read_odometer(self):
        '''Print a statement showing the car's mileage.'''
        print(f"This car has {self.odometer_reading} miles on it.")

    def update_odometer(self, mileage):
        '''
        Set the odometer reading to the given value.
        Reject the change if it attempts to roll the odometer back.
        '''
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")

    def increment_odometer(self, miles):
        '''Add the given amount to the odometer reading.'''
        self.odometer_reading += miles
    
my_new_car = Car('audi', 'a4', '2024')
print(my_new_car.get_descriptive_name())

my_new_car.update_odometer(23)
my_new_car.read_odometer()

my_used_car = Car('subaru', 'outback', 2019)
print(my_used_car.get_descriptive_name())

my_used_car.update_odometer(23_500)
my_used_car.read_odometer()

my_used_car.increment_odometer(100)
my_used_car.read_odometer()
my_used_car.fuel_capacity()

# %% [markdown]
# # Composition
# using class instances as attributes.
# Here,
# class Battery instance is being used as attribute in class ElectricCar.

# %%
class Battery():
    '''A simple attempt to model a battery for an electric car.'''

    def __init__(self, battery_size=40):
        '''Initialize the battery's attributes.'''
        self.battery_size = battery_size

    def describe_battery(self):
        '''Print a statement describing the battery size.'''
        print(f"This car has a {self.battery_size}-kWh battery.")

# %%
class ElectricCar(Car):
    '''Represent aspects of a car, specific to electric vehicles.'''

    def __init__(self, make, model, year):
        '''
        Initialize attributes of the parent class.
        Then intialize attributes specific to an electric car.
        '''
        super().__init__(make, model, year)
        self.battery = Battery()

    def fuel_capacity(self): # overriding the method of parent class.
        '''Print a statement describing the battery size.'''
        print(f"This car has a {self.battery_size}-kWh battery.")



my_leaf = ElectricCar('nissan', 'leaf', 2024)

my_leaf.fuel_capacity() # This car has a 40-kWh battery.
my_used_car.fuel_capacity() # This car has fuel capacity of 25L.

my_leaf.battery.describe_battery()

# %% [markdown]
# importing classes and methods through differend modules.

# %%
from vehicle import Car
# importing single class

my_new_car = Car('audi', 'a4', 2024)
my_new_car.odometer_reading = 23

my_new_car.read_odometer()

# %%
from vehicle import ElectricCar, Car
# importing multiple classes
my_new_car = Car('audi', 'a4', 2024)
my_new_car.odometer_reading = 23
my_new_car.read_odometer()

my_leaf = ElectricCar('nissan', 'leaf', 2024)
print(my_leaf.get_descriptive_name())
my_leaf.battery.describe_battery()

# %%
import vehicle
#importing entire module
my_new_car = vehicle.Car('audi', 'a4', 2024)
my_new_car.odometer_reading = 23
my_new_car.read_odometer()

# %%
from random import choice

players = ['charles', 'martina', 'michael', 'florence', 'eli']
first_up = choice(players)
first_up

# %% [markdown]
# # File Handling

# %%
from pathlib import Path

path = Path('pi_digits.txt')
contents = path.read_text()
pi_string = ''

lines = contents.splitlines()
for line in lines:
    pi_string += line.lstrip()

print(pi_string)
print(len(pi_string))
# Out:
# 3.141592653589793238462643383279
# 32

# %%
from pathlib import Path

path = Path('pi_million_digits.txt')
contents = path.read_text()
pi_string = ''

lines = contents.splitlines()

for line in lines:
    pi_string += line.lstrip()

print(f"{pi_string[:52]}...")
print(len(pi_string))

birthday = input("Enter you birhtday, in the form mmddyy: ")
if birthday in pi_string:
    print("Your birhtday appears in the first million digits of pi.")
else:
    print("Your birthday doesn't appear in the first million digits of pi.")

# %%
from pathlib import Path

contents = "I love programming.\n"
contents += "I love creating new games.\n"
contents += "I also love working with data.\n"
path = Path('programming.txt')
path.write_text(contents)

# %% [markdown]
# Book exercise

# %%
from pathlib import Path

guests_list = ''
path = Path('guest.txt')
is_running = True

while is_running:
    guest = input("Enter your name: ")
    guests_list += f"- {guest}\n"
    path.write_text(guests_list)

    check_continue = input("Continue? (y/n)")
    if check_continue.lower() == 'n':
        is_running = False

# %% [markdown]
# # Exception Handling

# %%
try:
    print(5/0)
except ZeroDivisionError:
    print("You can't divide by zero!")

# %%
print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")

while True:
    first_number = input("\n First number: ")
    if first_number == 'q':
        break
    second_number = input("\n Second number: ")
    if second_number == 'q':
        break
    try:
        answer = int(first_number) / int(second_number)
    
    except ZeroDivisionError:
        print("You can't divide by 0!")
    else:
        print(answer)

# %%
from pathlib import Path

path = Path("alice.txt")

def count_words(path):
    '''Coun the approximate number of words in a file.'''
    try:
        contents = path.read_text(encoding='utf-8')
    except FileNotFoundError:
        print("Sorry, the file {path} does not exist.")
    else:
        # Count the approximate number of words in the file.
        words = contents.split()
        num_words = len(words)
        print(f"The file {path} has about {num_words} words.")

count_words(path)

# %% [markdown]
# use pass in except to fail silently.

# %% [markdown]
# Storing data in JSON format

# %%
# Dumping data to JSON file.
from pathlib import Path
import json

numbers = [2, 3, 4, 7, 11, 13]

path = Path('number.json')
contents = json.dumps(numbers)
path.write_text(contents)

# %%
# Reading data from JSON file.
from pathlib import Path
import json

path = Path("number.json")
contents = path.read_text()
numbers = json.loads(contents) # loads string containing JSON data.

print(numbers)

# %% [markdown]
# Saving and reading user-generated data

# %%
from pathlib import Path
import json

username = input("What is your name? ")

path = Path("username.json")
contents = json.dumps(username)
path.write_text(contents)

print(f"We'll remember you when you come back, {username}!")
# Out:
# We'll remember you when you come back, world!

# %%
from pathlib import Path
import json

path = Path('username.json')
if path.exists():
    contents = path.read_text()
    username = json.loads(contents)
    print(f"Welcome back, {username}")
else:
    username = input("What is your name? ")
    path = Path("username.json")
    contents = json.dumps(username)
    path.write_text(contents)
    print(f"We'll remember you when you come back, {username}!")

# %% [markdown]
# Refactoring the above script
# breaking it into function for readability.

# %%
from pathlib import Path
import json

def get_stored_username(path):
    '''Get stored username if available.'''
    if path.exists():
        contents = path.read_text()
        if contents:
            username = json.loads(contents)
            return username
        else:
            return None
    
def get_new_username(path):
    '''Prompt for a new username.'''
    username = input("What is you name? ")
    contents = json.dumps(username)
    path.write_text(contents)
    return username
    
def greet_user():
    '''Greet the user by name.'''
    path = Path('username.json')
    username = get_stored_username(path)
    if username:
        print(f"Welcome back, {username}")
    else:
        username = get_new_username(path)
        print(f"We'll remember you when you come back, {username}!")

greet_user()
